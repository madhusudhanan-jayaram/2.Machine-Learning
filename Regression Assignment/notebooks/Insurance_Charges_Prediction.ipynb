# %%
#importing the Libraies
import pickle
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVR
from sklearn import tree
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# One-hot encode categorical columns
dataset = pd.get_dummies(dataset, columns=['sex', 'smoker'], drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
# Step 2: Split into features (X) and target (y)
independent=dataset[['age', 'bmi', 'children', 'sex_male','smoker_yes']]

# %%
dependent=dataset[["charges"]]

# %%
# Step 3: Train-test split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
# ----------------------------------
# ▶️ Multiple Linear Regression (MLR)
# ----------------------------------
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
r2_mlr= r2_score(y_test, y_pred)

# %%
# -------------------------
# ▶️ Support Vector Regression
# -------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svr = SVR(kernel='rbf')
svr.fit(X_train_scaled, y_train)
y_pred_svr = svr.predict(X_test_scaled)
r2_svr = r2_score(y_test, y_pred_svr)
# Out:
# C:\Users\mukil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# -------------------------
# ▶️ Decision Tree with Hyperparameter Tuning
# -------------------------
param_grid = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error','poisson'],
    'splitter': ['best', 'random'],
    'max_features': [None, 'sqrt', 'log2', 0.8, 5]  # mix of types to try
}

# %%
dtr = DecisionTreeRegressor(random_state=0)
grid_search = GridSearchCV(dtr, param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(X_train, y_train)

# Best estimator prediction
best_dtr = grid_search.best_estimator_
y_pred_dtr = best_dtr.predict(X_test)
r2_dtr = r2_score(y_test, y_pred_dtr)

# Random Forest parameter grid
rf_params = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2', None],  # removed 'auto'
    'bootstrap': [True]
}
rfr = RandomForestRegressor(random_state=42)
rf_grid = GridSearchCV(rfr, rf_params, cv=5, scoring='r2', n_jobs=-1)
rf_grid.fit(X_train, y_train.values.ravel())

best_rfr = rf_grid.best_estimator_
y_pred_rfr = best_rfr.predict(X_test)
r2_rfr = r2_score(y_test, y_pred_rfr)

# %%
# Print summary of all grid search results sorted by mean test score
results = pd.DataFrame(grid_search.cv_results_)
results = results.sort_values(by='mean_test_score', ascending=False)

# %%
# -------------------------
# ✅ Print Results Summary
# -------------------------
print("\nModel Evaluation Summary:")
print("----------------------------")
print(f"Multiple Linear Regression R² Score : {r2_mlr:.4f}")
print(f"Support Vector Regression R² Score  : {r2_svr:.4f}")
# Print all hyperparameter results
print("\nDecision Tree Hyperparameter Tuning Results:")
print("----------------------------------------------------")
results = grid_search.cv_results_
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"R2 Score: {mean_score:.4f} | Parameters: {params}")
print(f"Best Decision Tree R² Score from CV      : {grid_search.best_score_:.4f}")
print(f"Best Decision Tree Parameters            : {grid_search.best_params_}")
print(f"Decision Tree R² Score on Test Set       : {r2_dtr:.4f}")

print("Random Forest Best Params:", rf_grid.best_params_)
print(f"Random Forest Test R2 Score: {r2_rfr:.4f}\n")

# Print all Random Forest CV results in requested format
print("All Random Forest CV Results:")
results_df = pd.DataFrame(rf_grid.cv_results_)
results_df = results_df[['mean_test_score', 'params']].sort_values(by='mean_test_score', ascending=False)

for _, row in results_df.iterrows():
    print(f"R2 Score: {row['mean_test_score']:.4f} | Parameters: {row['params']}")
# Out:
# Model Evaluation Summary:
# ----------------------------
# Multiple Linear Regression R² Score : 0.7895
# Support Vector Regression R² Score  : -0.0834
#
# Decision Tree Hyperparameter Tuning Results:
# ----------------------------------------------------
# R2 Score: 0.6673 | Parameters: {'criterion': 'squared_error', 'max_features': None, 'splitter': 'best'}
# R2 Score: 0.6510 | Parameters: {'criterion': 'squared_error', 'max_features': None, 'splitter': 'random'}
# R2 Score: 0.6513 | Parameters: {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}
# R2 Score: 0.6009 | Parameters: {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'}
# R2 Score: 0.6513 | Parameters: {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}
# R2 Score: 0.6009 | Parameters: {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'}
# R2 Score: 0.6545 | Parameters: {'criterion': 'squared_error', 'max_features': 0.8, 'splitter': 'best'}
# R2 Score: 0.6616 | Parameters: {'criterion': 'squared_error', 'max_features': 0.8, 'splitter': 'random'}
# R2 Score: 0.6673 | Parameters: {'criterion': 'squared_error', 'max_features': 5, 'splitter': 'best'}
# R2 Score: 0.6510 | Parameters: {'criterion': 'squared_error', 'max_features': 5, 'splitter': 'random'}
# R2 Score: 0.6572 | Parameters: {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'best'}
# R2 Score: 0.6419 | Parameters: {'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'random'}
# R2 Score: 0.6519 | Parameters: {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}
# R2 Score: 0.6108 | Parameters: {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'}
# R2 Score: 0.6519 | Parameters: {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}
# R2 Score: 0.6108 | Parameters: {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}
# R2 Score: 0.6539 | Parameters: {'criterion': 'friedman_mse', 'max_features': 0.8, 'splitter': 'best'}
# R2 Score: 0.6599 | Parameters: {'criterion': 'friedman_mse', 'max_features': 0.8, 'splitter': 'random'}
# R2 Score: 0.6572 | Parameters: {'criterion': 'friedman_mse', 'max_features': 5, 'splitter': 'best'}
# R2 Score: 0.6419 | Parameters: {'criterion': 'friedman_mse', 'max_features': 5, 'splitter': 'random'}
# R2 Score: 0.6254 | Parameters: {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'}
# R2 Score: 0.6689 | Parameters: {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}
# R2 Score: 0.6260 | Parameters: {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}
# R2 Score: 0.6291 | Parameters: {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}
# R2 Score: 0.6260 | Parameters: {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}
# R2 Score: 0.6291 | Parameters: {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}
# R2 Score: 0.6581 | Parameters: {'criterion': 'absolute_error', 'max_features': 0.8, 'splitter': 'best'}
# R2 Score: 0.6542 | Parameters: {'criterion': 'absolute_error', 'max_features': 0.8, 'splitter': 'random'}
# R2 Score: 0.6254 | Parameters: {'criterion': 'absolute_error', 'max_features': 5, 'splitter': 'best'}
# R2 Score: 0.6689 | Parameters: {'criterion': 'absolute_error', 'max_features': 5, 'splitter': 'random'}
# R2 Score: 0.6449 | Parameters: {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}
# R2 Score: 0.6727 | Parameters: {'criterion': 'poisson', 'max_features': None, 'splitter': 'random'}
# R2 Score: 0.6491 | Parameters: {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}
# R2 Score: 0.5799 | Parameters: {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'}
# R2 Score: 0.6491 | Parameters: {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}
# R2 Score: 0.5799 | Parameters: {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}
# R2 Score: 0.6626 | Parameters: {'criterion': 'poisson', 'max_features': 0.8, 'splitter': 'best'}
# R2 Score: 0.6522 | Parameters: {'criterion': 'poisson', 'max_features': 0.8, 'splitter': 'random'}
# R2 Score: 0.6449 | Parameters: {'criterion': 'poisson', 'max_features': 5, 'splitter': 'best'}
# R2 Score: 0.6727 | Parameters: {'criterion': 'poisson', 'max_features': 5, 'splitter': 'random'}
# Best Decision Tree R² Score from CV      : 0.6727
# Best Decision Tree Parameters            : {'criterion': 'poisson', 'max_features': None, 'splitter': 'random'}
# Decision Tree R² Score on Test Set       : 0.7019
# Random Forest Best Params: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# Random Forest Test R2 Score: 0.8900
#
# All Random Forest CV Results:
# R2 Score: 0.8380 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8380 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8379 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8378 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8326 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8325 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8319 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8318 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8298 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8298 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8294 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8294 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8293 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8293 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8275 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8275 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8275 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8275 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8270 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8270 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8266 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8266 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8261 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8261 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8259 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8259 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8257 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8257 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8257 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8257 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8248 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8248 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8247 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8247 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8247 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8247 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8245 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8245 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8243 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8243 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8241 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8241 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8240 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8240 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8231 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8231 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8222 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8214 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8212 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8212 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8210 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8203 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8198 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8195 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8189 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8188 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8188 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8177 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8177 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8175 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8121 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8109 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# R2 Score: 0.8109 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8101 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8101 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8092 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# R2 Score: 0.8091 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8091 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8052 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.8032 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# R2 Score: 0.8012 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# R2 Score: 0.7988 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
