# %%
#importing the Libraies
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# One-hot encode categorical columns
dataset = pd.get_dummies(dataset, columns=['sex', 'smoker'], drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
# Split into features (X) and target (y)
independent=dataset[['age', 'bmi', 'children', 'sex_male','smoker_yes']]

# %%
dependent=dataset[["charges"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=1/3, random_state=0)

# %%
# Initialize the StandardScaler
# This scaler will standardize features by removing the mean and scaling to unit variance
sc = StandardScaler()

# Fit the scaler on the training data and transform it
# This computes the mean and standard deviation from X_train and applies scaling
X_train = sc.fit_transform(X_train)

# Transform the test data using the same parameters learned from X_train
# IMPORTANT: We only use transform (not fit_transform) to avoid data leakage
X_test = sc.transform(X_test)

# %%
# Define a grid of hyperparameters to search
param_grid = {
    'kernel': ['rbf', 'poly', 'sigmoid', 'linear'],   # Different kernel functions to try
    'C': [10, 100, 1000, 2000, 3000],                  # Regularization parameter (higher = less regularization)
    'gamma': ['auto', 'scale']                        # Kernel coefficient for 'rbf', 'poly', and 'sigmoid'
}

# Set up GridSearchCV with SVR model
grid = GridSearchCV(
    estimator=SVR(),              # Model to optimize
    param_grid=param_grid,        # Dictionary of hyperparameters
    refit=True,                   # Automatically refit the best model on the full training set
    verbose=3,                    # Print progress during fitting
    n_jobs=-1                     # Use all CPU cores to speed up the search
)

# Fit the model using Grid Search
# It will train and evaluate SVR for every combination of parameters in param_grid
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\mukil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# Get the cross-validation results as a dictionary
re = grid.cv_results_

# Print the best parameters found by GridSearchCV
print("The R² score value for the best parameters {}:".format(grid.best_params_))

# Print the best R² score achieved during cross-validation
print("Best R² score from Grid Search: {:.4f}".format(grid.best_score_))
# Out:
# The R² score value for the best parameters {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:
# Best R² score from Grid Search: 0.7998

# %%
# Convert the GridSearchCV results dictionary (cv_results_) into a pandas DataFrame
# This makes it easier to view, filter, and sort all the hyperparameter combinations and their performance
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.050302      0.006442         0.022601        0.004254       10
# 1        0.034364      0.001432         0.007612        0.000740       10
# 2        0.049656      0.001363         0.010528        0.001380       10
# 3        0.041682      0.005290         0.010328        0.003665       10
# 4        0.057431      0.006257         0.022644        0.004325       10
# 5        0.034165      0.002243         0.006484        0.000937       10
# 6        0.054164      0.003711         0.013876        0.001640       10
# 7        0.041942      0.002532         0.008447        0.001037       10
# 8        0.046843      0.001966         0.020525        0.000732      100
# 9        0.039493      0.003047         0.007890        0.000848      100
# 10       0.055716      0.001952         0.011428        0.001290      100
# 11       0.046532      0.007409         0.007210        0.002207      100
# 12       0.048755      0.009639         0.024944        0.009102      100
# 13       0.039497      0.006395         0.007404        0.002069      100
# 14       0.049843      0.002079         0.010429        0.000923      100
# 15       0.041472      0.005124         0.007615        0.001661      100
# 16       0.054832      0.003005         0.018688        0.000782     1000
# 23           0.598398           0.586104           0.573860
# 24           0.764261           0.818616           0.794131
# 25           0.784782           0.847674           0.807280
# 26          -0.432695          -0.346330          -0.484052
# 27           0.592446           0.586953           0.572862
# 28           0.764022           0.818319           0.794133
# 29           0.784713           0.847781           0.807295
# 30          -0.421011          -0.350248          -0.483750
# 31           0.592446           0.586953           0.572862
# 32           0.772917           0.846181           0.811601
# 33           0.783304           0.852190           0.810160
# 34          -1.629662          -1.461919          -1.712710
# 35           0.588893           0.587076           0.572849
# 36           0.772801           0.846034           0.811601
# 37           0.783163           0.852345           0.810160
# 38          -2.010670          -1.468842          -1.712109
# 39           0.588893           0.587076           0.572849
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.103473        -0.057387        0.056205               35
# 1           -0.050823         0.000826        0.054025               32
# 2           -0.051470        -0.004978        0.058648               34
# 3            0.297825         0.355112        0.063693               25
# 4           -0.103510        -0.057395        0.056230               36
# 5           -0.050317         0.000877        0.053658               31
# 6           -0.051337        -0.004968        0.058595               33
# 7            0.297825         0.355112        0.063693               25
# 8            0.161756         0.229703        0.069348               29
# 9            0.413719         0.506281        0.056081               22
# 10           0.425516         0.474000        0.042447               23
# 11           0.537415         0.585008        0.032600               19
# 12           0.161488         0.229672        0.069604               30
# 13           0.415264         0.506299        0.055077               21
# 14           0.424226         0.473708        0.042461               24
# 15           0.537415         0.585008        0.032600               19
# 16           0.613293         0.691544        0.041718               11
# 17           0.719528         0.787499        0.035885                8
# 18           0.346868         0.282901        0.043415               28
# 19           0.556109         0.600119        0.045217               13
# 20           0.613122         0.691485        0.041876               12
# 21           0.719979         0.787808        0.036003                7
# 22           0.346175         0.315846        0.044478               27
# 23           0.556109         0.600119        0.045217               13
# 24           0.709676         0.775086        0.036986                9
# 25           0.745448         0.797957        0.033268                4
# 26          -0.076409        -0.399268        0.190629               38
# 27           0.556109         0.595666        0.039218               15
# 28           0.709586         0.775041        0.036992               10
# 29           0.745732         0.798046        0.033220                3
# 30          -0.087414        -0.342681        0.135687               37
# 31           0.556109         0.595666        0.039218               15
# 32           0.725697         0.790300        0.040188                5
# 33           0.748175         0.799749        0.034104                2
# 34          -0.929359        -1.505790        0.308601               39
# 35           0.557014         0.595130        0.039068               17
# 36           0.725615         0.790281        0.040189                6
# 37           0.748201         0.799808        0.034165                1
# 38          -0.961821        -1.561068        0.346643               40
# 39           0.557014         0.595130        0.039068               17

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
# Prepare the input in the format expected by the model (2D array)
input_features = [[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]

# Use the best estimator from GridSearchCV to predict the target value
Future_Prediction = grid.predict(input_features)

# Print the prediction result
print("Future Prediction = {}".format(Future_Prediction[0]))
# Out:
# Future Prediction = 3316415.7200434203
